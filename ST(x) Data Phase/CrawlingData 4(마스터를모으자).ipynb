# %% [markdown]
# ### API 키 입력

# %%
api_key = "RGAPI-4b642383-a8e2-4768-8b4f-f15e56615529" # gmail 계정

# %% [markdown]
# ### 라이브러리 Import

# %%
import pandas as pd
import time
import riotapis
import pickle

# %% [markdown]
# ### (4-1단계) 매치 ID로부터 경기 승/패 데이터 얻기

# %%
kinds = "Additional"
tier = "MASTER"
# 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND'
#divisions = ['I']
# 'IV', 'III', 'II', 'I'
rfile_name = "IDWinLose List/{0}/{1}/{1}IDWinLoseList".format(kinds, tier)
origIDWinLoseList = pd.read_pickle(rfile_name)
gameIdList = []
for idx in range(len(origIDWinLoseList)):
    gameIdList.append(origIDWinLoseList[idx][0])
origIDWinLoseList = 0 # release
k = 1000
wholeLength = len(gameIdList)
for i in range(4, 5):
    start, end = 20*k*(i-1), 20*k*i
    pGameIdList = gameIdList[start:end]
    print(" >> Processing: {} - {} in length {} start".format(start, end, wholeLength))
    IDWinLoseList = riotapis.getIDWinLoseList(pGameIdList, api_key)
    sfile_name = "IDWinLose List/{}IDWinLoseList{}".format(tier, i)
    with open(sfile_name, 'wb') as f:
        pickle.dump(IDWinLoseList, f)
    print("{} saved\n".format(sfile_name))
    IDWinLoseList = 0
# Out:
#  >> Processing: 60000 - 80000 in length 116526 start
# status : 200, loop location : 0/20000, processing : 0.0%
# status : 200, loop location : 50/20000, processing : 0.2%
# status : 429, loop location : 100/20000, processing : 0.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 100/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 150/20000, processing : 0.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 166/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 199/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 200/20000, processing : 1.0%
# status : 200, loop location : 250/20000, processing : 1.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 299/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 300/20000, processing : 1.5%
# status : 200, loop location : 350/20000, processing : 1.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 368/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 398/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 400/20000, processing : 2.0%
# status : 200, loop location : 450/20000, processing : 2.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 498/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 500/20000, processing : 2.5%
# status : 200, loop location : 550/20000, processing : 2.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 598/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 600/20000, processing : 3.0%
# status : 200, loop location : 650/20000, processing : 3.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 698/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 700/20000, processing : 3.5%
# status : 200, loop location : 750/20000, processing : 3.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 774/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 797/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 800/20000, processing : 4.0%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 842/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 850/20000, processing : 4.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 896/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 900/20000, processing : 4.5%
# status : 200, loop location : 950/20000, processing : 4.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 996/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1000/20000, processing : 5.0%
# status : 200, loop location : 1050/20000, processing : 5.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1075/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1095/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 1100/20000, processing : 5.5%
# status : 200, loop location : 1150/20000, processing : 5.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1174/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1194/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 1200/20000, processing : 6.0%
# status : 200, loop location : 1250/20000, processing : 6.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1294/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1300/20000, processing : 6.5%
# status : 200, loop location : 1350/20000, processing : 6.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1394/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1400/20000, processing : 7.0%
# status : 200, loop location : 1450/20000, processing : 7.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1494/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1500/20000, processing : 7.5%
# status : 200, loop location : 1550/20000, processing : 7.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1594/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1600/20000, processing : 8.0%
# status : 200, loop location : 1650/20000, processing : 8.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1694/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1700/20000, processing : 8.5%
# status : 200, loop location : 1750/20000, processing : 8.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1794/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 1800/20000, processing : 9.0%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1821/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1833/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1845/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 1850/20000, processing : 9.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1891/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 61s
#     RECOVERED!
#
# status : 200, loop location : 1900/20000, processing : 9.5%
# status : 200, loop location : 1950/20000, processing : 9.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 1991/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 2000/20000, processing : 10.0%
# status : 200, loop location : 2050/20000, processing : 10.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2091/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 2100/20000, processing : 10.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2127/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 2150/20000, processing : 10.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2190/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 2200/20000, processing : 11.0%
# status : 200, loop location : 2250/20000, processing : 11.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2290/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 2300/20000, processing : 11.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2340/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 2350/20000, processing : 11.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2365/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2388/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 71s
#     RECOVERED!
#
# status : 200, loop location : 2400/20000, processing : 12.0%
# status : 200, loop location : 2450/20000, processing : 12.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2488/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 2500/20000, processing : 12.5%
# status : 200, loop location : 2550/20000, processing : 12.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2588/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 71s
#     RECOVERED!
#
# status : 200, loop location : 2600/20000, processing : 13.0%
# status : 200, loop location : 2650/20000, processing : 13.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2688/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 72s
#     RECOVERED!
#
# status : 200, loop location : 2700/20000, processing : 13.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2709/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2717/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 11s
#     RECOVERED!
#
# status : 200, loop location : 2750/20000, processing : 13.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2786/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 51s
#     RECOVERED!
#
# status : 200, loop location : 2800/20000, processing : 14.0%
# status : 404, loop location : 2850/20000, processing : 14.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2850/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2855/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 11s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2884/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 50s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2895/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 2900/20000, processing : 14.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2932/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 12s
#     RECOVERED!
#
# status : 200, loop location : 2950/20000, processing : 14.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2957/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 11s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2981/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 30s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 2987/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 11s
#     RECOVERED!
#
# status : 200, loop location : 3000/20000, processing : 15.0%
# status : 200, loop location : 3050/20000, processing : 15.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3079/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 51s
#     RECOVERED!
#
# status : 200, loop location : 3100/20000, processing : 15.5%
# status : 200, loop location : 3150/20000, processing : 15.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3179/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 61s
#     RECOVERED!
#
# status : 200, loop location : 3200/20000, processing : 16.0%
# status : 200, loop location : 3250/20000, processing : 16.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3273/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3278/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 61s
#     RECOVERED!
#
# status : 200, loop location : 3300/20000, processing : 16.5%
# status : 200, loop location : 3350/20000, processing : 16.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3378/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 3400/20000, processing : 17.0%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3412/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 3450/20000, processing : 17.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3459/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3476/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 71s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3495/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 3500/20000, processing : 17.5%
# status : 200, loop location : 3550/20000, processing : 17.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3575/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 3600/20000, processing : 18.0%
# status : 200, loop location : 3650/20000, processing : 18.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 3675/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
# ...
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 18900/20000, processing : 94.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 18925/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 18950/20000, processing : 94.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 18961/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 18974/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19000/20000, processing : 95.0%
# status : 200, loop location : 19050/20000, processing : 95.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19060/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 19100/20000, processing : 95.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19128/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19150/20000, processing : 95.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19159/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19193/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19200/20000, processing : 96.0%
# status : 200, loop location : 19250/20000, processing : 96.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19258/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# status : 200, loop location : 19300/20000, processing : 96.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19308/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19350/20000, processing : 96.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19357/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19391/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19400/20000, processing : 97.0%
# status : 200, loop location : 19450/20000, processing : 97.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19456/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19496/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19500/20000, processing : 97.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19515/20000
#     (0th trial) Current status: 404
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19550/20000, processing : 97.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19554/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 71s
#     RECOVERED!
#
# status : 200, loop location : 19600/20000, processing : 98.0%
# status : 200, loop location : 19650/20000, processing : 98.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19654/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 19700/20000, processing : 98.5%
# status : 200, loop location : 19750/20000, processing : 98.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19754/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 19800/20000, processing : 99.0%
# status : 200, loop location : 19850/20000, processing : 99.2%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19854/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (8th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 91s
#     RECOVERED!
#
# status : 200, loop location : 19900/20000, processing : 99.5%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19933/20000
#     (0th trial) Current status: 504
#     > unexpected status returned!!
#     > program would retry to solve it
#     > if it lasts tool long, please click stop button in jupyter
#     > do not afraid, it will not stop program
#     > only passing to this sample would be happened
#     > Even if you dont press it, it give this sample up after 3 minutes
#
#     total error wait time : 10s
#     RECOVERED!
#
# status : 200, loop location : 19950/20000, processing : 99.8%
#     [INVALID STATUS] : infinite loop start
#     If it doesnt solve it in 3 minutes, it gives up
#     loop location : 19953/20000
#     (0th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (1th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (2th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (3th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (4th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (5th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (6th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#     (7th trial) Current status: 429
#     > api cost full
#     > try 10 second wait time
#
#     total error wait time : 81s
#     RECOVERED!
#
# IDWinLose List/MASTERIDWinLoseList4 saved

# %% [markdown]
# ### (4-2단계) IDWinLoseList로부터 Timeline Response Object 얻기

# %%
tiers = ['PLATINUM']
# 'BRONZE', 'SILVER', 'GOLD', 'PLATINUM', 'DIAMOND'
divisions = ['II']
# 'IV', 'III', 'II', 'I'

for tier in tiers:
    for division in divisions:
        print("{0} {1} start".format(tier, division))
        IDWinLoseList = pd.read_pickle("./IDWinLose List/"+tier+division+"IDWinLoseList")
        ResponseObjects = riotapis.getTimelineResponseObject(IDWinLoseList, api_key)
        fileName = './Timeline Response Objects/'+tier+division+'ResponseObjects'
        with open(fileName, 'wb') as f:
            pickle.dump(ResponseObjects, f)
        print(tier, division, "Timeline Response Objects saved")
