# %% [markdown]
# ## Bring end timelines and target vector

# %%
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
import pickle
import sys , numpy as np
mod = sys.modules[__name__]
seed = 0

# %%
# initialize
kinds = "Additional"
tier = "MASTER"

"""
# Additional, Train
filePath = "./Refined Timeline DataFrames/{0}/{1}/Train/{1}{2}.csv"
endTimes = pd.read_pickle("endtimes/{}/Train/{}endTimes.pkl".format(kinds, tier))
"""

#"""
# Additional, Test
filePath = "./Refined Timeline DataFrames/{0}/{1}/Test/{1}{2}.csv"
endTimes = pd.read_pickle("endtimes/{}/Test/{}endTimes.pkl".format(kinds, tier))
#"""

"""
# Original
filePath = "./Refined Timeline DataFrames/{0}/{1}/{1}{2}.csv"
endTimes = pd.read_pickle("endtimes/{}/{}endTimes.pkl".format(kinds, tier))
"""

k = 1000
start, end = 1, 50
dataset = []

# get target vector 
df = pd.read_csv(filePath.format(kinds, tier, 20))
target = np.array(df['blue_win'])
print("len(endTimes): {}".format(len(endTimes)))
print("len(target): {}".format(len(target)))
# Out:
# len(endTimes): 20000
# len(target): 20000

# %% [markdown]
# ### NaN 검사 + Target 길이와 확인

# %%
print("-------------------------------------------------")
for tl in range(1, 51):
    # Additional, Train
    df = pd.read_csv("./Refined Timeline DataFrames/{0}/{1}/Train/{1}{2}.csv".format(kinds, tier, tl))
    # Additional, Test
    #df = pd.read_csv("./Refined Timeline DataFrames/{0}/{1}/Test/{1}{2}.csv".format(kinds, tier, tl))
    # Original
    #df = pd.read_csv("./Refined Timeline DataFrames/{0}/{1}/{1}{2}.csv".format(kinds, tier, tl))
    
    print("Before delete, {0}{1}.csv DataFrame's shape is".format(tier, tl), df.shape)
    df_dropna = df.dropna(axis=0)
    #df_dropna.to_csv("./Timeline DataFrames/{0}/{0}{1}.csv".format(tier, tl), index=False)
    print("After delete, {0}{1}.csv DataFrame's shape is".format(tier, tl), df_dropna.shape)
    print("-------------------------------------------------")
print("\nAll of works have been finished")

# %%
for tl in range(start, end+1):
    df = pd.read_csv(filePath.format(kinds, tier, tl))
    del df['game_id']
    del df['blue_win']
    setattr(mod, "df_{}".format(tl), df)
eval("df_"+str(35))
# Out:
#        total_gold  current_gold  total_level  avg_level  kills_total_minion  \
# 0            2585          1852            0        0.0                   6
# 1           -2992         -4059            0        0.0                  15
# 2           11575          3882           10        2.0                 100
# 3           11170          4250           10        2.0                 126
# 4            5872          5337            4        0.8                  -7
# ...           ...           ...          ...        ...                 ...
# 19995      -13713          2037           -9       -1.8                  -7
# 19996        8139          5009            6        1.2                 113
# 19997        2125         -2800            3        0.6                  10
# 19998       14645         -2543            4        0.8                  36
# 19999      -16366         -1916           -4       -0.8                 -17
#
#        kills_total_jungle_minion  first_blood  kills  deaths  assists  ...  \
# 0                              0            1      6      -6       -3  ...
# 1                              0           -1     -8       8      -33  ...
# 2                             46           -1     10     -10       12  ...
# 3                             11            1     11     -11        9  ...
# 4                             38            1     10     -10       21  ...
# ...                          ...          ...    ...     ...      ...  ...
# 19995                        -39           -1    -26      26      -27  ...
# 19996                         32           -1     -2       2       -7  ...
# 19997                       -145            1     -6       6       45  ...
# 19998                         14           -1     32     -32       32  ...
# 19999                        -72           -1    -28      28      -19  ...
#
#        kills_total_towers  kills_mid_towers  kills_top_towers  \
# 0                       0                 0                 0
# 1                      -2                -2                 0
# 2                       3                 2                 1
# 3                       6                 2                 1
# 4                       4                 4                -1
# ...                   ...               ...               ...
# 19995                  -9                -5                -1
# 19996                   6                 4                 1
# 19997                 -10                -4                -3
# 19998                   9                 5                 3
# 19999                 -11                -5                -3
#
#        kills_bot_towers  kills_inhibitors  first_dragon  total_dragons  \
# 0                     0                 2             0              0
# 1                     0                -1             0              0
# 2                     0                 0            -1              0
# 3                     3                -1             1              2
# 4                     1                -1             1              3
# ...                 ...               ...           ...            ...
# 19995                -3                -3            -1             -2
# 19996                 1                 2             1              2
# 19997                -3                -4            -1             -2
# 19998                 1                 2            -1              0
# 19999                -3                -3             1              0
#
#        rift_heralds  first_baron  total_barons
# 0                 0            0             0
# 1                 0            0             0
# 2                -1            0             0
# 3                 1            0             0
# 4                 0            0             0
# ...             ...          ...           ...
# 19995             0            0             0
# 19996             0            0             0
# 19997             0           -1            -1
# 19998             0            0             0
# 19999             0            0             0
#
# [20000 rows x 24 columns]

# %%
target

# %%
df_35[:10]

# %%
eval("df_"+str(35)).iloc[1]

# %% [markdown]
# ## Make dataset(not split train/dataset)

# %%
numMatches = len(endTimes)
print(" > {} {} real rnn dataset processing start".format(kinds, tier))
print("Whole game size is:", numMatches)
import time
#RNN_m 모델을 학습시키기 위한 데이터, 타겟 생성
print("-----------------------------------------------------")

"""
# Additional, Train
file_name_data = "RNN Real Dataset/{0}/{1}/Train/Data/{1}{2}.pkl"
file_name_target = "RNN Real Dataset/{0}/{1}/Train/Target/{1}{2}.pkl"
"""

#"""
# Additional, Test
file_name_data = "RNN Real Dataset/{0}/{1}/Test/Data/{1}{2}.pkl"
file_name_target = "RNN Real Dataset/{0}/{1}/Test/Target/{1}{2}.pkl"
#"""

"""
# Original
file_name_data = "RNN Real Dataset/{0}/{1}/Data/{1}{2}.pkl"
file_name_target = "RNN Real Dataset/{0}/{1}/Target/{1}{2}.pkl"
"""

total_time = time.time()
for m in range(2, 51):
    start_time = time.time()
    print(" >> Processing: RNN_{} model's data & target".format(m))
    dataset, eachTarget = [], []
    for idx in range(numMatches):
        endTime = endTimes[idx]
        miniset = []
        if m <= endTime:
            for k in range(1, m+1):
                miniset.append(eval("df_{}".format(k)).iloc[idx])
            dataset.append(np.array(miniset))
            eachTarget.append(target[idx])
    dataset = np.array(dataset)
    with open(file_name_data.format(kinds, tier, m), "wb") as f:
        pickle.dump(dataset, f)
    with open(file_name_target.format(kinds, tier, m), "wb") as f:
        pickle.dump(eachTarget, f)
    print("Saved. dataset.shape: {}, len(target): {}".format(dataset.shape, len(eachTarget)))
    print("Wait time: {} second(s)".format(round(time.time()-start_time, 2)))
    print("-----------------------------------------------------")
print("\nTotal wait time: {} second(s)".format(round(time.time()-total_time, 2)))
print("All of works have been finished")
# Out:
#  > Additional MASTER real rnn dataset processing start
# Whole game size is: 20000
# -----------------------------------------------------
#  >> Processing: RNN_2 model's data & target
# Saved. dataset.shape: (20000, 2, 24), len(target): 20000
# Wait time: 4.59 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_3 model's data & target
# Saved. dataset.shape: (20000, 3, 24), len(target): 20000
# Wait time: 6.76 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_4 model's data & target
# Saved. dataset.shape: (20000, 4, 24), len(target): 20000
# Wait time: 8.99 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_5 model's data & target
# Saved. dataset.shape: (19971, 5, 24), len(target): 19971
# Wait time: 11.13 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_6 model's data & target
# Saved. dataset.shape: (19851, 6, 24), len(target): 19851
# Wait time: 13.16 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_7 model's data & target
# Saved. dataset.shape: (19851, 7, 24), len(target): 19851
# Wait time: 15.4 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_8 model's data & target
# Saved. dataset.shape: (19846, 8, 24), len(target): 19846
# Wait time: 17.62 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_9 model's data & target
# Saved. dataset.shape: (19834, 9, 24), len(target): 19834
# Wait time: 19.7 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_10 model's data & target
# Saved. dataset.shape: (19809, 10, 24), len(target): 19809
# Wait time: 21.92 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_11 model's data & target
# Saved. dataset.shape: (19711, 11, 24), len(target): 19711
# Wait time: 23.89 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_12 model's data & target
# Saved. dataset.shape: (19590, 12, 24), len(target): 19590
# Wait time: 25.96 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_13 model's data & target
# Saved. dataset.shape: (19444, 13, 24), len(target): 19444
# Wait time: 28.87 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_14 model's data & target
# Saved. dataset.shape: (19223, 14, 24), len(target): 19223
# Wait time: 29.75 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_15 model's data & target
# Saved. dataset.shape: (18891, 15, 24), len(target): 18891
# Wait time: 31.27 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_16 model's data & target
# Saved. dataset.shape: (18453, 16, 24), len(target): 18453
# Wait time: 32.46 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_17 model's data & target
# Saved. dataset.shape: (18025, 17, 24), len(target): 18025
# Wait time: 33.7 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_18 model's data & target
# Saved. dataset.shape: (16388, 18, 24), len(target): 16388
# Wait time: 33.56 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_19 model's data & target
# Saved. dataset.shape: (15440, 19, 24), len(target): 15440
# Wait time: 32.27 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_20 model's data & target
# Saved. dataset.shape: (14742, 20, 24), len(target): 14742
# Wait time: 32.54 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_21 model's data & target
# Saved. dataset.shape: (13799, 21, 24), len(target): 13799
# Wait time: 31.82 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_22 model's data & target
# Saved. dataset.shape: (12844, 22, 24), len(target): 12844
# Wait time: 33.16 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_23 model's data & target
# Saved. dataset.shape: (11550, 23, 24), len(target): 11550
# Wait time: 29.23 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_24 model's data & target
# Saved. dataset.shape: (10438, 24, 24), len(target): 10438
# Wait time: 27.5 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_25 model's data & target
# Saved. dataset.shape: (9393, 25, 24), len(target): 9393
# Wait time: 25.75 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_26 model's data & target
# Saved. dataset.shape: (8334, 26, 24), len(target): 8334
# Wait time: 23.86 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_27 model's data & target
# Saved. dataset.shape: (7388, 27, 24), len(target): 7388
# Wait time: 21.94 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_28 model's data & target
# Saved. dataset.shape: (6496, 28, 24), len(target): 6496
# Wait time: 19.96 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_29 model's data & target
# Saved. dataset.shape: (5618, 29, 24), len(target): 5618
# Wait time: 17.87 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_30 model's data & target
# Saved. dataset.shape: (4818, 30, 24), len(target): 4818
# Wait time: 15.86 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_31 model's data & target
# Saved. dataset.shape: (4113, 31, 24), len(target): 4113
# Wait time: 13.99 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_32 model's data & target
# Saved. dataset.shape: (3434, 32, 24), len(target): 3434
# Wait time: 12.02 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_33 model's data & target
# Saved. dataset.shape: (2832, 33, 24), len(target): 2832
# Wait time: 10.19 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_34 model's data & target
# Saved. dataset.shape: (2339, 34, 24), len(target): 2339
# Wait time: 8.68 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_35 model's data & target
# Saved. dataset.shape: (1867, 35, 24), len(target): 1867
# Wait time: 7.11 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_36 model's data & target
# Saved. dataset.shape: (1472, 36, 24), len(target): 1472
# Wait time: 5.82 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_37 model's data & target
# Saved. dataset.shape: (1111, 37, 24), len(target): 1111
# Wait time: 4.5 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_38 model's data & target
# Saved. dataset.shape: (855, 38, 24), len(target): 855
# Wait time: 3.56 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_39 model's data & target
# Saved. dataset.shape: (658, 39, 24), len(target): 658
# Wait time: 2.82 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_40 model's data & target
# Saved. dataset.shape: (487, 40, 24), len(target): 487
# Wait time: 2.14 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_41 model's data & target
# Saved. dataset.shape: (364, 41, 24), len(target): 364
# Wait time: 1.64 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_42 model's data & target
# Saved. dataset.shape: (254, 42, 24), len(target): 254
# Wait time: 1.18 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_43 model's data & target
# Saved. dataset.shape: (168, 43, 24), len(target): 168
# Wait time: 0.8 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_44 model's data & target
# Saved. dataset.shape: (124, 44, 24), len(target): 124
# Wait time: 0.61 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_45 model's data & target
# Saved. dataset.shape: (88, 45, 24), len(target): 88
# Wait time: 0.44 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_46 model's data & target
# Saved. dataset.shape: (56, 46, 24), len(target): 56
# Wait time: 0.29 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_47 model's data & target
# Saved. dataset.shape: (40, 47, 24), len(target): 40
# Wait time: 0.21 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_48 model's data & target
# Saved. dataset.shape: (22, 48, 24), len(target): 22
# Wait time: 0.12 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_49 model's data & target
# Saved. dataset.shape: (16, 49, 24), len(target): 16
# Wait time: 0.09 second(s)
# -----------------------------------------------------
#  >> Processing: RNN_50 model's data & target
# Saved. dataset.shape: (12, 50, 24), len(target): 12
# Wait time: 0.07 second(s)
# -----------------------------------------------------
#
# Total wait time: 746.77 second(s)
# All of works have been finished
