# %%
import pandas as pd
import numpy as np
import time
from riotapis import calc
s = 1000 # metric: millisecond
start, end, minute = 1, 50, 60*s

# %% [markdown]
# ## Get Timeline DataFrames

# %% [markdown]
# ### Original Timeline Response Objects

# %%
kinds = 'Original'
tier = 'DIAMOND'
divisions = ['III', 'II', 'I']
file = "../Timeline Response Objects/{0}/{1}/{1}{2}ResponseObjects"
#file = "../Timeline Response Objects/{}{}ResponseObjects"
for m in range(start, end+1):
    print("\n=========================================")
    start_time = time.time()
    df = pd.DataFrame()
    print("\n>> Processing : {} minutes\n".format(m))
    for division in divisions:
        print("-----------------------------------------")
        ResponseObjects = pd.read_pickle(file.format(kinds, tier, division))
        print(">> >> {} {} ResponseObjects loaded".format(tier, division))
        _df = calc(ResponseObjects, m*minute)
        df = pd.concat([df, _df])
        ResponseObjects = 0 # release memoriers\
        print("-----------------------------------------")
    df.to_csv("./Timeline DataFrames/{0}/{1}/{1}{2}.csv".format(kinds, tier, m), index=False)
    print("Done. Wait time: {} second(s)".format(round(time.time()-start_time, 1)))
    print("\n=========================================")
print("All of works have been finished")

# %% [markdown]
# ### Additional Timeline Response Objects

# %% [markdown]
# #### For training dataset

# %%
kinds = 'Additional'
tier = 'CHALLENGER'
file = "../Timeline Response Objects/{0}/{1}/{1}ResponseObjects{2}"
files = [i for i in range(1, 2)] # 1 to 1
for m in range(start, end+1):
    start_time = time.time()
    df = pd.DataFrame()
    print("\n=========================================")
    print(">> Processing : {} minutes".format(m))
    for i in files:
        print("-----------------------------------------")
        print(">> >> ResponseObjects {} loaded".format(i))
        ResponseObjects = pd.read_pickle(file.format(kinds, tier, i))
        _df = calc(ResponseObjects, m*minute)
        df = pd.concat([df, _df])
        ResponseObjects = 0 # release memoriers\
        print("-----------------------------------------")
    df.to_csv("./Timeline DataFrames/{0}/{1}/Train/{1}{2}.csv".format(kinds, tier, m), index=False)
    print("Done. Wait time: {} second(s)".format(round(time.time()-start_time, 1)))
    print("=========================================\n")
print("All of works have been finished")
# Out:
# =========================================
# >> Processing : 1 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 184.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 2 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 128.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 3 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 129.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 4 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 140.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 5 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 153.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 6 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 150.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 7 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 152.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 8 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 153.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 9 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 155.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 10 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 156.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 11 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 156.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 12 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 157.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 13 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 158.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 14 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 162.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 15 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 155.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 16 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 153.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 17 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 150.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 18 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 154.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 19 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 155.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 20 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 157.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 21 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 160.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 22 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 161.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 23 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 160.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 24 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 162.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 25 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 163.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 26 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 163.9 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 27 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 161.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 28 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 163.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 29 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 165.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 30 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 160.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 31 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 173.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 32 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 173.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 33 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 181.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 34 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 175.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 35 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 176.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 36 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 176.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 37 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 175.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 38 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 177.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 39 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 177.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 40 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 184.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 41 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 177.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 42 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 179.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 43 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 177.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 44 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 177.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 45 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 178.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 46 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 178.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 47 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 186.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 48 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 178.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 49 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 180.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 50 minutes
# -----------------------------------------
# >> >> ResponseObjects 1 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# 6000th sample data crawling success
# 8000th sample data crawling success
# 10000th sample data crawling success
# 12000th sample data crawling success
# 14000th sample data crawling success
# 16000th sample data crawling success
# 18000th sample data crawling success
# 20000th sample data crawling success
# 22000th sample data crawling success
# 24000th sample data crawling success
# 26000th sample data crawling success
# 28000th sample data crawling success
# 30000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 179.4 second(s)
# =========================================
#
# All of works have been finished

# %% [markdown]
# #### For test dataset

# %%
kinds = 'Additional'
tier = 'CHALLENGER'
files = [2] # 골:10 플+다:5 마스터:
file = "../Timeline Response Objects/{0}/{1}/{1}ResponseObjects{2}"
for m in range(start, end+1):
    start_time = time.time()
    df = pd.DataFrame()
    print("\n=========================================")
    print(">> Processing : {} minutes".format(m))
    for i in files:
        print("-----------------------------------------")
        print(">> >> ResponseObjects {} loaded".format(i))
        ResponseObjects = pd.read_pickle(file.format(kinds, tier, i))
        _df = calc(ResponseObjects, m*minute)
        df = pd.concat([df, _df])
        ResponseObjects = 0 # release memoriers\
        print("-----------------------------------------")
    df.to_csv("./Timeline DataFrames/{0}/{1}/Test/{1}{2}.csv".format(kinds, tier, m), index=False)
    print("Done. Wait time: {} second(s)".format(round(time.time()-start_time, 1)))
    print("=========================================\n")
print("All of works have been finished")
# Out:
# =========================================
# >> Processing : 1 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 2 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 23.9 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 3 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 4 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 23.5 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 5 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 23.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 6 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 23.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 7 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 8 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 9 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 23.9 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 10 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 23.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 11 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.9 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 12 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 13 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 14 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 15 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 16 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 17 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.9 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 18 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 19 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 20 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 21 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 22 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 23 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 24 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 25 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 26 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 27 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 28 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 29 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 30 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 31 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 32 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 33 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 34 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 35 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 36 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 37 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.3 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 38 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 39 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 40 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.0 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 41 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 42 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.4 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 43 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.8 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 44 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 45 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.6 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 46 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.1 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 47 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 48 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 24.7 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 49 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 25.2 second(s)
# =========================================
#
#
# =========================================
# >> Processing : 50 minutes
# -----------------------------------------
# >> >> ResponseObjects 2 loaded
# 2000th sample data crawling success
# 4000th sample data crawling success
# -----------------------------------------
# Done. Wait time: 26.5 second(s)
# =========================================
#
# All of works have been finished
